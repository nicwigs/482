# %% [markdown]
# # Exercise 2 Solution
#
# The purpose of this exercise is to help you get familiar with the Python tweepy library for downloading data from Twitter. Follow the instructions below to complete the exercise. Use the template notebook below to write and execute your python program. Rename the template file as exercise2.ipynb and submit it via D2L. You should also convert the notebook to PDF or HTML and submit the converted file as well.

# %% [markdown]
# **Step 1.** Create a Twitter account and create a new Twitter application using the account. Make sure you write down your consumer and access tokens and secret keys.

# %% [markdown]
# **Step 2.** Following the Python tweepy example given in the lecture, use the Twitter Search (REST) API to download 30 most recent tweets from the Twitter feed of â€œCDCgovâ€.  This can be done by changing the keyword string given in the sample code to â€œfrom:CDCgovâ€. For more information about the query term to use, read the documentation available at https://dev.twitter.com/rest/public/search. Make sure you install tweepy on your machine before running the code. Save the text messages of the returned tweets into an ASCII text file named cdc.txt. **Make sure you save only the text part of the tweet message NOT the entire JSON message** (which includes username, coordinates, etc). See the example given in the lecture notes on how to access the text part of the tweets.  The following is an example about how to save a string into a file:
#
# with open(â€œfilenameâ€,â€wâ€) as f:
#
#     text = â€œthis is a stringâ€
# 	f.write(text)
#     f.write(â€œ\nâ€)
#
# **Solution:**

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import API

# Replace the X's with your consumer tokens and access tokens.
# To create the application, go to https://dev.twitter.com

C_KEY = 'XXXXXXX'
C_SECRET = 'XXXXXXX'
A_TOKEN_KEY = 'XXXXXXX'
A_TOKEN_SECRET = 'XXXXXXX'

auth = tweepy.OAuthHandler(C_KEY, C_SECRET)
auth.set_access_token(A_TOKEN_KEY, A_TOKEN_SECRET)
api = tweepy.API(auth)

keyword = 'CDCgov'
posts = api.search(q=keyword,count=30)

with open('cdc.txt', 'w') as f:
    for tweet in posts:
        f.write(str(tweet.text.encode("utf-8")))
        f.write('\n')

# %% [markdown]
# ---
# **Step 3.** Use the Twitter Streaming API to download tweets containing the keyword â€œhealthâ€. Set the time limit to 30 seconds and store the results into a file named health.json.
#
# **Solution:**

# %%
import time
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

C_KEY = 'XXXXXXX'
C_SECRET = 'XXXXXXX'
A_TOKEN_KEY = 'XXXXXXX'
A_TOKEN_SECRET = 'XXXXXXX'

# Create a StreamListener class 
class MyListener(StreamListener):

    def __init__(self, time_limit=30):
        self.start_time = time.time()
        self.limit = time_limit
        self.outFile = open('health.json', 'w')
        super(MyListener, self).__init__()
    
    def on_data(self, data):
        if (time.time() - self.start_time) < self.limit:
            self.outFile.write(data.strip())     
            self.outFile.write('\n') 
            return True
        else:
            self.outFile.close()
            return False

    def on_error(self, status):
        print(status)
        
auth = OAuthHandler(C_KEY,C_SECRET)
auth.set_access_token(A_TOKEN_KEY,A_TOKEN_SECRET)
myStream = Stream(auth, MyListener(time_limit=30))
myStream.filter(track=[ 'health'])

# %%
# Checking to make sure that your json file is stored correctly.
# If the json.loads command fails, modify your on_data() method to the following
# to deal with the newline character at the end of each tweet message:
#    self.outFile.write(data.strip())   
#    self.outFile.write('\n') 

import json

with open('health.json') as f:
    tweets = [json.loads(line) for line in f]
    for twt in tweets:
        print(twt['id'], 'posted', twt['text'], '\n')
# Out:
# 1087895614493466625 posted @SamHeughan hi Sam, just saw youâ€™re movie â€œThe Spy.....â€ u were wonderful!!! U would be the perfect Bond; dashing sâ€¦ https://t.co/X6oTlNOHo8
#
# 1087895614711611393 posted This is murder. Plan and Simple. @POTUS @VP where is a judge to stop this?
#
# 1087895616867483648 posted RT @drtlaleng: Abortion is Health Care.
#
# #RoeAt46 https://t.co/pvhzx3ztU8
#
# 1087895617538408448 posted RT @rajniwadhwa902: #StayFitStayHealthySaysStMSG  Saint Dr Gurmeet Ram Rahim Singh Ji Insan educates the young generation to be health consâ€¦
#
# 1087895618561998859 posted RT @SitaramYechury: Wealth of top 9 billionaires, is equivalent to the bottom 50%. Centre &amp; states together spend on medical, public healthâ€¦
#
# 1087895618595573761 posted Everyday I see where coaches stand with athletes, I wonder do they ever know when pushing someone too hard is enougâ€¦ https://t.co/Hg8A41t5Ui
#
# 1087895619056881668 posted RT @conservmillen: Late term abortions now legalized in NY, in which a fully formed ~6lb child is poisoned to death. God forgive us for beiâ€¦
#
# 1087895620403253249 posted RT @conservmillen: Late term abortions now legalized in NY, in which a fully formed ~6lb child is poisoned to death. God forgive us for beiâ€¦
#
# 1087895620646510597 posted @evil_betch So glad to hear that Sharon is an expert on mental health! Is she a Psychiatrist? A Psychiatric Nurse Practitioner?
#
# 1087895621078601729 posted RT @conservmillen: Late term abortions now legalized in NY, in which a fully formed ~6lb child is poisoned to death. God forgive us for beiâ€¦
#
# 1087895621598674944 posted RT @obianuju: Today New York State Senate passed the Reproductive Health Act which redefines person asâ€œa human being who has been born andâ€¦
#
# 1087895621896417280 posted RT @Pink_About_it: New york state senate just passed a bill under reproductive health act, which now legalizes full term abortions.
#
# Whatâ€¦
#
# 1087895622970159104 posted RT @AndrewTaverrite: COOL THINGS TODAY:
# -46th anniversary of Roe v Wade
# -the courts just struck down Iowa's draconian 6-week abortion ban
# -â€¦
#
# 1087895625767706624 posted RT @jjave_: reminder: you are not selfish for completely removing yourself from situations that harm your mental health. take care of yoursâ€¦
#
# 1087895628150013953 posted RT @patrick_ye: Kaylene Ready (Myriad Womenâ€™s Health): barriers to access to genetic counseling include: only 5,000 genetic counselors in tâ€¦
#
# 1087895628703768576 posted SEND MY GIRL SOME LOVE
#
# 1087895628737331200 posted @Asmongold do u see this shit
#
# 1087895627743281152 posted Saint Dr. @Gurmeetramrahim Singh Ji Insan says that sports are mandatory for physical fitness. Games must be playedâ€¦ https://t.co/Xsrv9pbCVJ
#
# 1087895628942901248 posted @JohnCarltonKing @NoRestrictions @PPNYCAction John I donâ€™t disagree with you even tho you seem very angry. Iâ€™m poinâ€¦ https://t.co/UKTfD3LmB9
#
# 1087895629081264128 posted RT @VKT1031: #StayFitStayHealthySaysStMSG
# https://t.co/CyCT8ip1oy
#  à¤—à¥à¤°à¥à¤œà¥€ à¤¦à¥à¤µà¤¾à¤°à¤¾ à¤¶à¤¾à¤¹ à¤¸à¤¤à¤¨à¤¾à¤® à¤œà¥€ à¤¶à¤¿à¤•à¥à¤·à¤£ à¤¸à¤‚à¤¸à¥à¤¥à¤¾à¤¨ à¤•à¥‡ à¤›à¤¾à¤¤à¥à¤°à¥‹à¤‚ à¤•à¥‹ à¤–à¥‡à¤²à¥‹à¤‚ à¤•à¤¾ à¤ªà¥à¤°à¤¶à¤¿à¤•à¥â€¦
#
# 1087895629106479104 posted RT @JamesOKeefeIII: Of all the good, true and beautiful things in life to fight and cheer for, why would you do so for more late term abortâ€¦
#
# 1087895627374182401 posted Women sing "Health Songs" written by them in the night meeting organised @RGMVP Training and Resource Development Câ€¦ https://t.co/OAyS9yNpG4
#
# 1087895629899149312 posted RT @Kanew: "740,000 people uninsured, it's a shame and a disgrace for Tennessee not to expand medicaid... it's POLICY MURDER. And don't telâ€¦
#
# 1087895630196940800 posted RT @Pink_About_it: New york state senate just passed a bill under reproductive health act, which now legalizes full term abortions.
#
# Whatâ€¦
#
# 1087895631807635456 posted Of my actual health issues, none of them were caused by my weight, but all of them are a product of the chronic anxâ€¦ https://t.co/53LngOoTTZ
#
# 1087895632264744960 posted RT @bedlamfury: Vaccine-preventable diseases will remain a threat in Malaysia as long as some parents resist vaccination for their childrenâ€¦
#
# 1087895633669713920 posted RT @KristenKP43: Of course the Ford government would hold up data on sexual assaults. They've cut mental health services and did not providâ€¦
#
# 1087895635410341889 posted RT @goodsababu: This (the bird flu scare) is one of the examples cited in Michael Lewis's "The Fifth Risk," about how Trump et al. have disâ€¦
#
# 1087895635641200640 posted RT @JordanUhl: WOW
#
# @AOC: "I do think that a system that allows billionaires to exist when there are parts of Alabama where people are stilâ€¦
#
# 1087895636052193280 posted RT @RepCasten: 1 in 4 women have an abortion in her lifetime. A woman's right to make her own health care decisions is fundamental and poliâ€¦
#
# 1087895636803022849 posted Shhh.
#
# 1087895637717409792 posted RT @AlexMLeo: Just saw a Fox News segment in which they referenced @AOC saying it's immoral that billionaires coexist in a country with "peâ€¦
#
# 1087895640431099904 posted RT @rmead777: ðŸš¨Legalized InfanticideðŸš¨
#
# "The bill adds a broad â€œhealthâ€ exception for abortions after 24 weeks. The exception would allow woâ€¦
#
# 1087895642754764800 posted RT @AlotusNine: Merry Christmas to all of you!ðŸ˜˜ðŸŒ²â¤ï¸May you and your loved ones be blessed with health, goodies, love, money and happiness.â€¦
#
# 1087895643081850882 posted Well, we are glad you are open. Thanks goodness MCES is a nonprofit and not run by the government!
#
# 1087895642192506880 posted Australia's #Great Barrier Reef is under a health check as a 25-day data collecting journey is carried out, canvassâ€¦ https://t.co/LYM765QQip
#
# 1087895643719376897 posted RT @MNHouseInfo: SESSION DAILY: More students than ever need mental health services, education officials tell joint House hearing https://tâ€¦
#
# 1087895644449185792 posted RT @spiritual_mami: STOP ROMANTICIZING MENTAL ILLNESSES!
# fuck, itâ€™s not â€œcuteâ€ having absolutely no control over your own emotions, thoughâ€¦
#
# 1087895644444844032 posted RT @SenGillibrand: Remember: Abortion existed before #RoevWade, it just wasn't legal or safe. Women died without that access to the healthâ€¦
#
# 1087895644851777536 posted RT @GURKIRTANINSAN: #StayFitStayHealthySaysStMSG
# Saint Dr Gurmeet Ram Rahim Singh Ji Insan Says That As U Wake Up In the Morning, have 1-2â€¦
#
# 1087895645661417472 posted @keithgow Oh man, living here, in the belly of the beast, is a constant exercise in mental health management. I litâ€¦ https://t.co/d53mIq9b6N
#
# 1087895645854277633 posted Our high school has a PLTW program that addresses biomedical careers , and a health science program with sports medâ€¦ https://t.co/iRmdJcbESr
#
# 1087895646567309312 posted A1 If we are truly educators focused on teaching the whole child, that must include attentiveness to their social,â€¦ https://t.co/XpN4eGG9Rv
#
# 1087895646743552000 posted RT @redsteeze: He literally just made this claim in December of last year
# https://t.co/JVIY5yglZH https://t.co/1oq0VUF60Q
#
# 1087895648618336256 posted @emptywheel His mental health is so poor and his ego is so fractured, our country is suffering.
#
# 1087895648899280896 posted RT @merry123459: Is selling and using illegal drugs something the Ford family canâ€™t help getting involved in? This family has no concept ofâ€¦
#
# 1087895648874094593 posted RT @AOC: If we didnâ€™t laugh, weâ€™d cry https://t.co/XGrRQq4zUh
#
# 1087895649046093824 posted RT @ShashiTharoor: My welcome message for the International Ayush Conclave Kerala, to be held in Thiruvananthapuram Feb 15-18. At a time whâ€¦
#
# 1087895646743523333 posted Getting back to league since season starts soon uwu ADCs pls hit me up I'm so sick of randoms flashing into minionâ€¦ https://t.co/NMkWgC0u5O
#
# 1087895649792770048 posted RT @ProjectBuddy: Itâ€™s okay if today (or any day) was a bad day for your mental health. We canâ€™t always have good days. Please try to takeâ€¦
#
# 1087895650275127296 posted RT @AANAFoundation: The AANA Foundation sponsors critical research in support of nurse anesthesia. Learn more at https://t.co/dPekWKpU04â€¦
#
# 1087895650350571520 posted RT @AlexMLeo: Just saw a Fox News segment in which they referenced @AOC saying it's immoral that billionaires coexist in a country with "peâ€¦
#
# 1087895650631667712 posted RT @SpeakerPelosi: 46 years ago, #RoevWade affirmed that a woman's health decisions must be her own. Democrats are committed to defending wâ€¦
#
# 1087895650627284993 posted RT @PPact: For too many women of color and poor women, abortion access has never been a reality. Racism, discriminatory public policy, andâ€¦
#
# 1087895650883104768 posted RT @briantylercohen: AOC: "I do think a system that allows billionaires to exist when there are parts of Alabama where people are still getâ€¦
#
# 1087895651164184576 posted RT @feral_goddessx3: louder for the people in the back please https://t.co/BZVuinWSza
#
# 1087895651717832705 posted RT @csudvm2003: I just had an R21 funded, and it's time to recruit a postdoc! We will be defining transcriptional and translational changesâ€¦
#
# 1087895651986358272 posted RT @GaryLegum: "It's like fungus." Great, let's give Marc Thiessen ringworm and see if he still thinks that. https://t.co/SFaXB1TIBI
#
# 1087895654272323584 posted RT @Pink_About_it: New york state senate just passed a bill under reproductive health act, which now legalizes full term abortions.
#
# Whatâ€¦
#
# 1087895654385410048 posted Well said, Michael! #WeLEadEd
#
# 1087895655048200192 posted RT @shaileshinsha4: @Gurmeetramrahim
# @derasachasauda
# Staying fit and healthy is a top priority for many people but there are still some oâ€¦
#
# 1087895658101686272 posted RT @JamesOKeefeIII: Of all the good, true and beautiful things in life to fight and cheer for, why would you do so for more late term abortâ€¦
#
# 1087895659800342528 posted @SenBlumenthal Stopping a beating heart and ending a life is not health care. It is murder. Brutal and barbaric.
#
# 1087895659955527683 posted RT @TheCDHF: The new year is approaching! You and your child NEED to attend this special #event on on all things digestive, and overall heaâ€¦
#
# 1087895660282531840 posted Kevin are you kidding me, all youth sports are unsafe,driving in a car is unsafe but you never talk about it. You hâ€¦ https://t.co/FajVkJ2fRp
#
# 1087895660756496384 posted RT @SenGillibrand: Remember: Abortion existed before #RoevWade, it just wasn't legal or safe. Women died without that access to the healthâ€¦
#
# 1087895660819554309 posted Sacramento CA USA - RN Case Manager 125k Salary 100k Bonus Home Health CA - Comp Resource Group has : Comp Resourceâ€¦ https://t.co/SzUZKOAaXz
#
# 1087895661708750849 posted RT @SpeakerPelosi: 46 years ago, #RoevWade affirmed that a woman's health decisions must be her own. Democrats are committed to defending wâ€¦
#
# 1087895661784244235 posted RT @SunitaInsan0001: #StayFitStayHealthySaysStMSG Sports improve cardiovascular health, lower the blood prey, improve muscular strength, keâ€¦
#
# 1087895662061072384 posted RT @JordanUhl: WOW
#
# @AOC: "I do think that a system that allows billionaires to exist when there are parts of Alabama where people are stilâ€¦
#
# 1087895663164182528 posted RT @JordanUhl: WOW
#
# @AOC: "I do think that a system that allows billionaires to exist when there are parts of Alabama where people are stilâ€¦
#
# 1087895663243874304 posted RT @epmurphymn: Rep @mikehowardmn is authoring the Alec Smith Emergency Insulin legislation. Protecting the insulin producers is protectingâ€¦
#
# 1087895664636321792 posted RT @XHNews: Australia's #Great Barrier Reef is under a health check as a 25-day data collecting journey is carried out, canvassing bleach aâ€¦
#
# 1087895665848578048 posted RT @HillaryClinton: Forty-six years after Roe v. Wade, we reaffirm what will always be true: Women have an unalienable right to make theirâ€¦
#
# 1087895666381205507 posted RT @SenGillibrand: Remember: Abortion existed before #RoevWade, it just wasn't legal or safe. Women died without that access to the healthâ€¦
#
# 1087895666490204165 posted Citizens are wising up to the trickle down economics scam. Giving more tax cuts to companies and the upper 10% doesâ€¦ https://t.co/DpP32OgPoh
#
# 1087895666934902790 posted RT @ScrewedHumans: Anyone calling for violence against children who wear MAGA gear, on social media should get a visit from the FBI... Youâ€¦
#
# 1087895667610173440 posted RT @letat_lechat: https://t.co/SCAK7q3x1o
#
# 1087895668344012801 posted RT @DrLeroySr: LTTV NOW | Take Back Your Health! - Health Cometh to the Body of Christ - TUESDAY PM https://t.co/CklIm5dBAV
#
# 1087895668578869248 posted RT @TorontoStar: See ya meat ðŸ‘‹ Hello ðŸ¥¦ ! Health Canada just put out a new food guide and this is what they say you should be eating.
# https:â€¦
#
# 1087895668696309762 posted RT @anuragraj89: à¤¯à¥à¤µà¤¾à¤“ à¤¸à¥‡ à¤§à¥‹à¤–à¤¾ à¤”à¤° à¤œà¥à¤®à¤²à¥‡ à¤•à¤°à¤¨à¥‡ à¤•à¥‡ à¤¬à¤¾à¤¦ à¤…à¤­à¥€ à¤­à¥€ à¤µà¤¿à¤¶à¥à¤µà¤¾à¤¸ à¤¹à¥ˆ à¤•à¤¿ @BJP4UP à¤œà¥€à¤¤à¥‡ à¤œà¥€
# @BJP4UP à¤•à¥‹ à¤œà¤¡à¤¼ à¤¸à¥‡ à¤¸à¤¾à¤« à¤•à¤°à¤¨à¥‡ à¤•à¤¾ à¤•à¤¾à¤® à¤¹à¤® #BEDTET2011â€¦
#
# 1087895669006843904 posted @patbirdies @NoRestrictions @PPNYCAction The definition of health is the determination of a doctor, I.E. NOT YOU. Aâ€¦ https://t.co/Zw8bdH1H7g
#
# 1087895669665353728 posted RT @JordanUhl: WOW
#
# @AOC: "I do think that a system that allows billionaires to exist when there are parts of Alabama where people are stilâ€¦
#
# 1087895670273527808 posted RT @AOC: If we didnâ€™t laugh, weâ€™d cry https://t.co/XGrRQq4zUh
#
# 1087895671670067200 posted RT @ManishKasaur: #StayFitStayHealthySaysStMSG
# Saint Dr.@Gurmeetramrahim Singh Ji Says Healthy mind resides in a healthy body only. Sportsâ€¦
#
# 1087895672530063360 posted RT @laurenduca: You think NY is progressive? We only just passed the Reproductive Health Act. We only just banned conversion therapy. We *câ€¦
#
# 1087895672290869248 posted Special thanks to Dr. Lee Cowden, @ItsSuperDon &amp; you for helping me @rsbellmedia rock the health world on Theâ€¦ https://t.co/urWXxh63aK
#
# 1087895672542687232 posted RT @reubing: AOC has ringworm of the brain.
# Sad. https://t.co/xqHa3crGTe
#
# 1087895673150861313 posted The! #hcldr
#
# 1087895674358779905 posted RT @SenFeinstein: I remember what it was like before #RoevWade . I know the lengths women took so they could make their own decisions regarâ€¦
#
# 1087895675793219584 posted RT @jjave_: reminder: you are not selfish for completely removing yourself from situations that harm your mental health. take care of yoursâ€¦
#
# 1087895676141400066 posted Feelings of anger, bitterness, and hatred are negative. If I kept them inside me they would spoil my body and my health. They are of no use.
#
# 1087895676996923392 posted RT @rajni902: #StayFitStayHealthySaysStMSG Healthy mind resides in a healthy body only. Sports are a great way of promoting good health; noâ€¦
#
# 1087895677244448770 posted JOB; Jersey City NJ USA - Sr. Webmethods Developer/Architect - Medical Insurance Dental Insurance Vision : Medicalâ€¦ https://t.co/XgvGUFpSZw
#
# 1087895677445828608 posted RT @ScottGallatin: This is how you appease your conscience: The bill, dubbed the Reproductive Health Act, redefines a â€œpersonâ€ as â€œa  humanâ€¦
#
# 1087895678473375744 posted RT @SenSherrodBrown: Womenâ€™s personal, private health decisions are just that â€“ private â€“ and they must always be able to make them in consâ€¦
#
# 1087895678918017024 posted RT @nyc_viki: #StayFitStayHealthySaysStMSG
# Saint Dr Gurmeet Ram Rahim Singh Ji Insan educates the young generation to be health conscious *â€¦
#
# 1087895679043846144 posted @matfassarella https://t.co/Qjb4mnBbnI Aqui fala um pouco hehe.
#
# 1087895679073247232 posted RT @ACLU: BREAKING: New York just passed the Reproductive Health Act, which will finally bring state law in line with Roe. v. Wade.
#
# Thisâ€¦
#
# 1087895676678258688 posted RT @rashmiinsannrw: Regular exercise can help improve the overallÂ healthÂ of our entire cardiovascular system. Lowers risk of heart disease,â€¦
#
# 1087895680327344135 posted RT @sarsoss: Hooray, I hosted a live Q&amp;A without sweating excessively, or garbling! The Feb issue of North &amp; South - featuring my interviewâ€¦
#
# 1087895681073729536 posted RT @AlexMLeo: Just saw a Fox News segment in which they referenced @AOC saying it's immoral that billionaires coexist in a country with "peâ€¦
#
# 1087895682063708160 posted RT @spicedrum: @DrJenGunter I would proudly wear a Vaginal Anti-Christ pin should you choose to sell one. (perhaps with part of the proceedâ€¦
#
# 1087895682378285056 posted I've seen way more kids heavily involved in the church become teen parents so I hope that in this good year of ourâ€¦ https://t.co/4kgW6XEIZD
#
# 1087895682449473536 posted RT @PiousSoul2: #StayFitStayHealthySaysStMSG
# Health is wealth, and healthy mind resides in a healthy body only, St. @Gurmeetramrahim ji sayâ€¦
#
# 1087895683124867072 posted RT @AOC: If we didnâ€™t laugh, weâ€™d cry https://t.co/XGrRQq4zUh
#
# 1087895683141529600 posted RT @Kyukimasa: èµ°ã£ã¦é£›ã¶2è¶³æ­©è¡Œãƒ­ãƒœãƒƒãƒˆ
# https://t.co/tB3hJ2uK3Q
# èƒ´ä½“(é ­éƒ¨)ã®æ¨ªã«2é€£ãƒ­ãƒ¼ã‚¿ãƒ¼ãŒä»˜ã„ã¦ã¦ã‚¸ãƒ£ãƒ³ãƒ—å‹•ä½œã¨ã‹ã§ãã‚‹ã€‚å˜ã«ãƒžãƒ«ãƒã‚³ãƒ—ã‚¿ãƒ¼ã§é£›ã¹ã‚‹æ­©è¡Œãƒ­ãƒœãƒƒãƒˆã¨ã„ã†ã ã‘ã˜ã‚ƒãªãã¦è„šéƒ¨æ­©è¡Œã¨ã‚¹ãƒ©ã‚¹ã‚¿ã‚’çµ±åˆã—ãŸå‹•ãã‚’ç›®æŒ‡ã—ã¦ã‚‹ã‚ˆã†ã â€¦
#
# 1087895683481432064 posted RT @obianuju: Only a wicked person can celebrate â€œabortion rightsâ€ on the same day her daughter joyfully announces she is pregnant with a pâ€¦
#
# 1087895683976310785 posted A1:  Mental health is extremely important in not only schools but our society.  Ttâ€™s and Ssâ€™s both deal with mentalâ€¦ https://t.co/4GFQyc3CHu
#
# 1087895683640803329 posted #fitness #health #exercise #getfit Fight Boxing Ball Equipment With Head Band For Reflex Speed Training https://t.co/aOAbDUqbHc
#
# 1087895684882358272 posted RT @SenGillibrand: Remember: Abortion existed before #RoevWade, it just wasn't legal or safe. Women died without that access to the healthâ€¦
#
# 1087895684978798598 posted RT @conservmillen: Late term abortions now legalized in NY, in which a fully formed ~6lb child is poisoned to death. God forgive us for beiâ€¦
#
# 1087895685326884864 posted RT @ManishKasaur: #StayFitStayHealthySaysStMSG
# Saint Dr.@Gurmeetramrahim Singh Ji Says Healthy mind resides in a healthy body only. Sportsâ€¦
#
# 1087895685633056768 posted RT @FortniteFunny: When you ask your teammate if they have any heals and they say no but a minute later they somehow have full health. httpâ€¦
#
# 1087895685863694337 posted RT @emfvet78: Dear Tax Raider. So what youâ€™re saying is Hospitals and Doctors offices will offer their services for FREE? Or will it be theâ€¦
#
# 1087895686534889472 posted @Alyssa_Milano Just ignore them my dear Alyssa! I follow you as I first saw your true essence years ago pleading foâ€¦ https://t.co/IwZn5ctvQB
#
# 1087895686820057089 posted RT @FortniteFunny: When you ask your teammate if they have any heals and they say no but a minute later they somehow have full health. httpâ€¦
#
# 1087895690670473222 posted Tone deaf
#
# 1087895691169533953 posted @conservmillen And we wonder why we have mass shootings and sky rocketing murder rates? If you think mental healthâ€¦ https://t.co/hCZYITjpmN
#
# 1087895693061222401 posted RT @conservmillen: Late term abortions now legalized in NY, in which a fully formed ~6lb child is poisoned to death. God forgive us for beiâ€¦
#
# 1087895691404312576 posted It's pretty #OBVIOUS
# @realDonaldTrump is
# THE BIGGEST SINGLE
# #RISK to the
# #HEALTH &amp; #SAFETY of
# the #UNITEDSTATES.â€¦ https://t.co/zYlcmRaH6g
#
# 1087895694621532160 posted Theodore Roosevelt Cared Deeply About the Sick. Who Knew? https://t.co/zfuAT0HfnA #HealthCareForAll #healthcare #MedicareForAll
#
# 1087895695082713088 posted Most Common Diseases of 50plus: Pulmonary vascular disease(Respiratory disease): Pulmonary veno-occlusive disease -â€¦ https://t.co/0L7KpoS2cq
#
# 1087895695284232192 posted RT @Trump454545: Spare me the left's outrage over us questioning RBG's health!! If this was Clarence Thomas during Obama's terms they'd beâ€¦
#
# 1087895695397437441 posted RT @MsSmartyPanda: About 40,000 Americans die every year due to inability to afford healthcare. This is 12x the deaths thatâ€™s occurred duriâ€¦
#
# 1087895697385553920 posted RT @MaddowBlog: "Agents learned Thursday their supplemental health insurance, specifically vision and dental, will lapse if the shutdown exâ€¦
#
# 1087895697247088640 posted @anecdatally @EpiEllie Honestly, I think theyâ€™re 100% right.
#
# Also, and in no way related, we should really stop maâ€¦ https://t.co/JgiAbFZB4h
#
# 1087895698077564929 posted RT @xunhuas: #lrt The health drink that Jongdae brought along and handed out to the members enroute to the airport for their Kaohsiung tripâ€¦
#
# 1087895700766117888 posted RT @AlexMLeo: Just saw a Fox News segment in which they referenced @AOC saying it's immoral that billionaires coexist in a country with "peâ€¦
#
# 1087895701059784704 posted RT @PPNYCAction: BREAKING: New York State Senate just made HISTORY and passed the Reproductive Health Act on the anniversary of #RoevWade!â€¦
#
# 1087895701076340737 posted RT @TheRealNews: The Baltimore Sun recently reported that the #ChesapeakeBay's health rating fell from a C- to a D+  https://t.co/PBJoGoYSe1
#
# 1087895701827145728 posted RT @Kyukimasa: èµ°ã£ã¦é£›ã¶2è¶³æ­©è¡Œãƒ­ãƒœãƒƒãƒˆ
# https://t.co/tB3hJ2uK3Q
# èƒ´ä½“(é ­éƒ¨)ã®æ¨ªã«2é€£ãƒ­ãƒ¼ã‚¿ãƒ¼ãŒä»˜ã„ã¦ã¦ã‚¸ãƒ£ãƒ³ãƒ—å‹•ä½œã¨ã‹ã§ãã‚‹ã€‚å˜ã«ãƒžãƒ«ãƒã‚³ãƒ—ã‚¿ãƒ¼ã§é£›ã¹ã‚‹æ­©è¡Œãƒ­ãƒœãƒƒãƒˆã¨ã„ã†ã ã‘ã˜ã‚ƒãªãã¦è„šéƒ¨æ­©è¡Œã¨ã‚¹ãƒ©ã‚¹ã‚¿ã‚’çµ±åˆã—ãŸå‹•ãã‚’ç›®æŒ‡ã—ã¦ã‚‹ã‚ˆã†ã â€¦
#
# 1087895702221582336 posted Big 108RM player in MN!!!
#
# 1087895702615650304 posted RT @abstractnights: always make sure that your friends are ok during their depressive episodes but i do understand that in order to keep yoâ€¦
#
# 1087895704985452544 posted RT @SunitaA61483672: #StayFitStayHealthySaysStMSG Sports improve cardiovascular health, lower the blood pressure, improve muscular strengthâ€¦
#
# 1087895705157554176 posted Mental health and human rights in the 21st century - Puras - 2019 - World Psychiatry - Wiley Online Library https://t.co/6uo7pi9PiG
#
# 1087895706453434369 posted RT @OfficialKanjla: #StayFitStayHealthySaysStMSG
# Saint Dr. @Gurmeetramrahim Singh Ji Insan educates the young generation to be health conscâ€¦
#
# 1087895707665813504 posted RT @chrissyfarr: General rule with very few exceptions:
#
# Health-tech companies that start out trying to sell to doctors/consumers end up sâ€¦
#
# 1087895708072464384 posted RT @AnilKapoor: Please tell your sister to take care and all my good wishes and prayers for her quick recovery @aashish Chaturvedi https://â€¦
#
# 1087895708668182529 posted RT @SenGillibrand: Remember: Abortion existed before #RoevWade, it just wasn't legal or safe. Women died without that access to the healthâ€¦
#
# 1087895708613529600 posted RT @MAPGiftVoucher: Bertanya seputar kesehatan bisa dapet #MAPGiftVoucher gratis. Gimana caranya? Lihat tweet di bawah ini ya https://t.co/â€¦
#
# 1087895707648876544 posted #StayFitStayHealthySaysStMSG
# @Gurmeetramrahim
# Healthy mind resides in a healthy body only. Sports are a great way oâ€¦ https://t.co/CkrYWWrT9l
#
# 1087895709536407552 posted RT @AlexMLeo: Just saw a Fox News segment in which they referenced @AOC saying it's immoral that billionaires coexist in a country with "peâ€¦
#
# 1087895710111072256 posted Excess body fat is without question critical when considering everyones health and well-being, couple of the effectâ€¦ https://t.co/fAsqisMDCt
#
# 1087895710207565829 posted PSA
#
# If you have voted blue or even worse, plan on voting blue, then you better not come at me sideways for complaiâ€¦ https://t.co/yPGxF4J93s
#
# 1087895710798884864 posted RT @UniqueLover_: Healthy mind resides in a healthy body only.
# SportsðŸŽ¾âš½ðŸ€ðŸƒ are a great way of promoting good health; not only do we reap thâ€¦
#
# 1087895710941569025 posted RT @AmerAcadPeds: Wash hands, wash hands, wash hands! That remains some of the best advice to prevent children from catching colds, @Consumâ€¦
#
# 1087895712707289095 posted RT @Pink_About_it: New york state senate just passed a bill under reproductive health act, which now legalizes full term abortions.
#
# Whatâ€¦
#
# 1087895712984170496 posted RT @BryGotTheJuice: Itâ€™s important to be with someone who is good for your mental health just as much as they are your physical health.
#
# 1087895713277722626 posted #StayFitStayHealthySaysStMSG
# @GurmeetRamRahim Singh ji Insan educates the young generation to be health consciousâ€¦ https://t.co/btDGp2FFMt
#
# 1087895714309554176 posted RT @charliekirk11: New York City just unveiled a free health care plan for 600,000 NYC residents, including 300,000 illegal immigrants whoâ€¦
#
# 1087895714514882560 posted This #playlist: can improve your health: Best binaural beats playlist #SpotifyPlaylist #ListenFreeSpotifyâ€¦ https://t.co/d9SKdHLjIH
#
# 1087895714896773121 posted RT @PPact: This. Is. Huge.
#
# @NYGovCuomo JUST signed the Reproductive Health Act into law â€” a big win towards securing safe, legal abortionâ€¦
#
# 1087895714963906560 posted RT @PiousSoul2: #StayFitStayHealthySaysStMSG
# Health is wealth, and healthy mind resides in a healthy body only, St. @Gurmeetramrahim ji sayâ€¦
#
# 1087895715991511042 posted RT @AlexMLeo: Just saw a Fox News segment in which they referenced @AOC saying it's immoral that billionaires coexist in a country with "peâ€¦
#
# 1087895715324588033 posted RT @JamesOKeefeIII: Of all the good, true and beautiful things in life to fight and cheer for, why would you do so for more late term abortâ€¦
#
# 1087895716247281664 posted Fake ass
#
# 1087895717073555459 posted RT @blkgirlculture: Black women are three times more likely to die in child birth than women of any other race.
#
# Health professionals contâ€¦
#
# 1087895717195251712 posted RT @Prosperous0101: Dear God, I am praying for every person struggling with health, love life, financial, spiritual, family, marital, businâ€¦
#
# 1087895717597798400 posted CM @Naveen_Odisha announced upscaling of #DigitalDispensaries in the state; currently 30 DDs are operational inâ€¦ https://t.co/ooNomLyMZ3
#
# 1087895720110235649 posted RT @OfficialKanjla: #StayFitStayHealthySaysStMSG
# Saint Dr. @Gurmeetramrahim Singh Ji Insan educates the young generation to be health conscâ€¦
#
# 1087895720546500608 posted RT @isaiahhickland: reminder to all my friends starting school back up today:
#
# â€¢ be gentle &amp; patient with yourself
# â€¢ prioritize your mentalâ€¦
#
# 1087895699549696001 posted RT @AndreaTGabbadon: A1 If we are truly educators focused on teaching the whole child, that must include attentiveness to their social, emoâ€¦
#
# 1087895720659628032 posted RT @xunhuas: #lrt The health drink that Jongdae brought along and handed out to the members enroute to the airport for their Kaohsiung tripâ€¦
#
# 1087895721330782208 posted RT @taylorzombiesky: TAYLOR MOMSEN SMILING RT FOR GOOD LUCK GOOD HEALTH AND FORTUNE https://t.co/v26K0mcbmC
#
# 1087895721834098692 posted RT @conservmillen: Late term abortions now legalized in NY, in which a fully formed ~6lb child is poisoned to death. God forgive us for beiâ€¦
#
# 1087895722421309441 posted A1: We need to focus on mental health because our students come from many diverse background and lived experiences.â€¦ https://t.co/DlpXGptVDx
#
# 1087895724031848449 posted RT @jjave_: reminder: you are not selfish for completely removing yourself from situations that harm your mental health. take care of yoursâ€¦
#
# 1087895724476510208 posted RT @FortniteFunny: When you ask your teammate if they have any heals and they say no but a minute later they somehow have full health. httpâ€¦
#
# 1087895724300353536 posted nycgov: ICYMI: Executive Order builds on NYCMayor's commitment to guarantee health care for all, reminds eligible Nâ€¦ https://t.co/B3DUCrkO8b
#
# 1087895724497416192 posted RT @RealSexyCyborg: I can give the answer I give other Chinese, since I mostly know what's important to us. Chinese want to know why they sâ€¦
#
# 1087895724724011009 posted RT @DetheEshaSen: #NetajiSubhasChandraBose
#
# The Britishers heaped miseries on him nroke his health but were never able to break his spirit.â€¦
#
# 1087895724891820032 posted RT @RGMVP: Women sing "Health Songs" written by them in the night meeting organised @RGMVP Training and Resource Development Centre at Nigoâ€¦
#
# 1087895726183645185 posted https://t.co/qrrdv4ajgQ https://t.co/qrrdv4ajgQ
#
# 1087895726569521157 posted RT @blkgirlculture: Black women are three times more likely to die in child birth than women of any other race.
#
# Health professionals contâ€¦
#
# 1087895726804353026 posted RT @pinky_jharbade: #StayFitStayHealthySaysStMSG
# Sports improve cardiovascular health, lower the blood I, improve muscular strength,keep usâ€¦
#
# 1087895726934376448 posted RT @Trump454545: Spare me the left's outrage over us questioning RBG's health!! If this was Clarence Thomas during Obama's terms they'd beâ€¦
#
# 1087895730822500352 posted RT @BathLabourParty: If this was some disease causing all of those problems it would be a much higher priority, but because the victims canâ€¦
#
# 1087895731598512128 posted RT @conservmillen: Late term abortions now legalized in NY, in which a fully formed ~6lb child is poisoned to death. God forgive us for beiâ€¦
#
# 1087895732047278080 posted RT @HillaryClinton: Forty-six years after Roe v. Wade, we reaffirm what will always be true: Women have an unalienable right to make theirâ€¦
#
# 1087895732617601025 posted Research reveals health toll of increasing loneliness | Swinburne news https://t.co/ul1CPs2ZmQ
#
# 1087895733137801216 posted RT @AlexMLeo: Just saw a Fox News segment in which they referenced @AOC saying it's immoral that billionaires coexist in a country with "peâ€¦
#
# 1087895733293015041 posted This isnâ€™t Reproductive Health Care, this is straight up MURDER! #NewYork @andrewcuomo @HillaryClinton @PPFA
#
# 1087895734047916032 posted RT @SpeakerPelosi: 46 years ago, #RoevWade affirmed that a woman's health decisions must be her own. Democrats are committed to defending wâ€¦
#
# 1087895734685454336 posted RT @conservmillen: Late term abortions now legalized in NY, in which a fully formed ~6lb child is poisoned to death. God forgive us for beiâ€¦
#
# 1087895734710616065 posted RT @MalaRani14: #StayFitStayHealthySaysStMSG
# Saint Dr. @Gurmeetramrahim Singh Ji Insan educates the young generation to be health consciousâ€¦
#
# 1087895736522547200 posted RT @Pink_About_it: New york state senate just passed a bill under reproductive health act, which now legalizes full term abortions.
#
# Whatâ€¦
#
# 1087895736879075328 posted RT @AlexMLeo: Just saw a Fox News segment in which they referenced @AOC saying it's immoral that billionaires coexist in a country with "peâ€¦
#
# 1087895737583747072 posted RT @SpeakerPelosi: 46 years ago, #RoevWade affirmed that a woman's health decisions must be her own. Democrats are committed to defending wâ€¦
#
# 1087895737692708864 posted RT @ParkerMolloy: Capitalism: a system that gives people the freedom to get ringworm https://t.co/Y2OUsnOPTb
#
# 1087895738095411203 posted RT @conservmillen: Late term abortions now legalized in NY, in which a fully formed ~6lb child is poisoned to death. God forgive us for beiâ€¦

# %% [markdown]
# **Step 4:** Install MySQL server on your machine. Go to https://dev.mysql.com/downloads/ and download the installation files. After installing, create a user named 'cse482' with a password named 'cse482'. Create also a database named 'cse482'. To do this, login to the mysql client as administrator and then performed the following steps:
#
# mysql> CREATE USER 'cse482' IDENTIFIED BY 'cse482';
#
# mysql> CREATE DATABASE cse482;
#
# mysql> GRANT ALL PRIVILEGES ON cse482.* TO 'cse482'@'%';
#
# Note that the preceding commands are only available if you're the administrator of the database.

# %% [markdown]
# **Step 5:** Install the mysql-connector-python library. Create a mysql table named 'Health', which has the following 3 columns:
#
#     TweetID BIGINT PRIMARY KEY,
#
#     UserID BIGINT,
#
#     Message VARCHAR(200)

# %%
uname = "cse482"
pwd = "cse482"
hname = "localhost"
dbname = "cse482"

import mysql.connector
from mysql.connector import errorcode

try:
    cnx = mysql.connector.connect(user=uname, password=pwd, host=hname, database=dbname)
    cursor = cnx.cursor()
    query = "DROP TABLE IF EXISTS Health"
    cursor.execute(query)

    query = """ CREATE TABLE IF NOT EXISTS Health (TweetID bigint PRIMARY KEY, UserID bigint, Message varchar(200) )"""
    cursor.execute(query)
    cnx.commit()
    cursor.close()
    cnx.close()
except mysql.connector.Error as e:
    print(e.msg)       # error message

# %% [markdown]
# **Step 6:** Open the health.json file you've created. For each tweet, insert the tweetID, userID, and tweet text message into the Health table in MySQL.

# %%
import json
try:
    cnx = mysql.connector.connect(user=uname, password=pwd, host=hname, database=dbname)
    cursor = cnx.cursor()
    
    with open('health.json') as f:
        tweets = [json.loads(line) for line in f]
        for twt in tweets:
            tweetID = twt['id']
            userID = twt['user']['id']
            msg = twt['text']
            newmsg = msg.replace("'","\\'")

            query = "INSERT INTO Health VALUES (" + str(tweetID) + ",'" 
            query += str(userID) + "','" + newmsg + "')"
            cursor.execute(query)
            
    cnx.commit()
    cursor.close()
    cnx.close()
    
except mysql.connector.Error as e:
    print(e.msg)       # error message
